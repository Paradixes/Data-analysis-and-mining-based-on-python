# %%
import numpy as np
import operator
import sys
from PIL import Image
from os import listdir

# %%
#计算输入测试数据inx和已知样本的距离，并返回类别标签
def kNN(newInput,dataSet,labels,k):
    dataSetSize = dataSet.shape[0]
    diff = np.tile(newInput,(dataSetSize,1)) - dataSet
    squaredDiff = abs(diff ** 2)
    squaredDist = np.sum(squaredDiff,axis = 1)
    distances = squaredDist ** 0.5
    
    sortedDisIndicies = distances.argsort()
    
    classCount = {}
    for i in range(k):
        votellabel = labels[sortedDisIndicies[i]]
        classCount[votellabel] = classCount.get(votellabel,0) + 1
    
    sortedClassCount = sorted(classCount.items(),key=operator.itemgetter(1),reverse=True)
    return sortedClassCount[0][0]

# %%
#32*32的二进制图像矩阵转换为1*1024的向量
def img2vect(filename):
    returnVect = np.zeros((1,1024))
    fr = open(filename)
    for i in range (32):
        lineStr = fr.readline()
        for j in range(32):
            returnVect[0,32 * i + j] = int(lineStr[j])
    return returnVect

# %%
#手写数字识别系统的测试代码
def handwritingClassTest():
    hwLabels = []
    m = len(trainingFileList)
    trainingMat = np.zeros((m,1024))
    for i in range(m):
        fileNameStr = trainingFileList[i]
        fileStr = fileNameStr.split('.')[0]
        classNumStr = int(fileStr.split('_')[0])
        hwLabels.append(classNumStr)
        trainingMat[i,:] = img2vect('data/TT/%s' % fileNameStr)
        
    errorCount = 0.0
    mTest = len(testFileList)
    for i in range(mTest):
        fileNameStr = testFileList[i]
        fileStr = fileNameStr.split('.')[0]
        classNumStr = int(fileStr.split('_')[0])
        vectorUnderTest = img2vect('data/testfile_8/%s' % fileNameStr)
        classifierResult = kNN(vectorUnderTest, trainingMat, hwLabels, 2)
        print("%s\t%s" %(fileStr,classifierResult))
        a = str(classifierResult)
        b = str(fileStr)
        t = b + "\t" + a + "\n"
        with open("ResultX.txt","a") as f:
            f.write(t)

# %%
from os import listdir

# %%
handwritingClassTest()
# Out:
# 1	2
# 10	4
# 100	0
# 101	8
# 102	4
# 103	3
# 104	2
# 105	6
# 106	7
# 107	8
# 108	9
# 109	1
# 11	9
# 110	4
# 111	3
# 112	4
# 113	8
# 114	4
# 115	7
# 116	3
# 117	7
# 118	9
# 119	7
# 12	0
# 120	4
# 121	6
# 122	6
# 123	6
# 124	2
# 125	8
# 126	7
# 127	9
# 128	0
# 129	7
# 13	2
# 130	1
# 131	8
# 132	1
# 133	5
# 134	8
# 135	6
# 136	3
# 137	0
# 138	0
# 139	2
# 14	5
# 140	1
# 141	1
# 142	7
# 143	1
# 144	4
# 145	2
# 146	4
# 147	2
# 148	4
# 149	3
# 15	6
# 150	2
# 151	0
# 152	2
# 153	2
# 154	2
# 155	2
# 156	9
# 157	8
# 158	3
# 159	8
# 16	1
# 160	5
# 161	6
# 162	7
# 163	1
# 164	3
# 165	8
# 166	0
# 167	9
# 168	7
# 169	5
# 17	2
# 170	6
# 171	9
# 172	4
# 173	7
# 174	3
# 175	1
# 176	6
# 177	1
# 178	6
# 179	4
# 18	5
# 180	3
# 181	0
# 182	0
# 183	0
# 184	3
# 185	3
# 186	4
# 187	8
# 188	9
# 189	6
# 19	0
# 190	9
# 191	2
# 192	5
# 193	1
# 194	2
# 195	9
# 196	5
# 197	8
# 198	1
# 199	8
# 2	7
# 20	7
# 200	8
# 201	3
# 202	8
# 203	2
# 204	3
# 205	8
# 206	9
# 207	8
# 208	5
# 209	9
# 21	5
# 210	0
# 211	6
# 212	4
# ...

# %%
#手写数字识别系统的测试代码
def handwritingClassTest1():
    hwLabels = []
    m = len(trainingFileList)
    trainingMat = np.zeros((m,1024))
    for i in range(m):
        fileNameStr = trainingFileList[i]
        fileStr = fileNameStr.split('.')[0]
        classNumStr = int(fileStr.split('_')[0])
        hwLabels.append(classNumStr)
        trainingMat[i,:] = img2vect('data/TT/%s' % fileNameStr)
        
    errorCount = 0.0
    mTest = len(testFileList)
    for i in range(mTest):
        fileNameStr = testFileList[i]
        fileStr = fileNameStr.split('.')[0]
        classNumStr = int(fileStr.split('_')[0])
        vectorUnderTest = img2vect('data/testfile_8/%s' % fileNameStr)
        CR1 = kNN(vectorUnderTest, trainingMat, hwLabels, 3)
        CR2 = kNN(vectorUnderTest, trainingMat, hwLabels, 4)
        CR3 = kNN(vectorUnderTest, trainingMat, hwLabels, 6)
        if(CR1 != CR2 or CR1 != CR3 or CR2 != CR3):
            if(CR1 == CR2):
                classifierResult = CR1
            if(CR1 == CR3):
                classifierResult = CR1
            if(CR2 == CR3):
                classifierResult = CR2
            else:
                classifierResult = CR2
        else:
            classifierResult = CR1
        classifierResult = kNN(vectorUnderTest, trainingMat, hwLabels, 2)
        print("%s\t%s" %(fileStr,classifierResult))
        a = str(classifierResult)
        b = str(fileStr)
        t = b + "\t" + a + "\n"
        with open("ResultT.txt","a") as f:
            f.write(t)

# %%
handwritingClassTest1()
# Out:
# 1	2
# 10	4
# 100	0
# 101	8
# 102	4
# 103	3
# 104	2
# 105	6
# 106	7
# 107	8
# 108	9
# 109	1
# 11	9
# 110	4
# 111	3
# 112	4
# 113	8
# 114	4
# 115	7
# 116	3
# 117	7
# 118	9
# 119	7
# 12	0
# 120	4
# 121	6
# 122	6
# 123	6
# 124	2
# 125	8
# 126	7
# 127	9
# 128	0
# 129	7
# 13	2
# 130	1
# 131	8
# 132	1
# 133	5
# 134	8
# 135	6
# 136	3
# 137	0
# 138	0
# 139	2
# 14	5
# 140	1
# 141	1
# 142	7
# 143	1
# 144	4
# 145	2
# 146	4
# 147	2
# 148	4
# 149	3
# 15	6
# 150	2
# 151	0
# 152	2
# 153	2
# 154	2
# 155	2
# 156	9
# 157	8
# 158	3
# 159	8
# 16	1
# 160	5
# 161	6
# 162	7
# 163	1
# 164	3
# 165	8
# 166	0
# 167	9
# 168	7
# 169	5
# 17	2
# 170	6
# 171	9
# 172	4
# 173	7
# 174	3
# 175	1
# 176	6
# 177	1
# 178	6
# 179	4
# 18	5
# 180	3
# 181	0
# 182	0
# 183	0
# 184	3
# 185	3
# 186	4
# 187	8
# 188	9
# 189	6
# 19	0
# 190	9
# 191	2
# 192	5
# 193	1
# 194	2
# 195	9
# 196	5
# 197	8
# 198	1
# 199	8
# 2	7
# 20	7
# 200	8
# 201	3
# 202	8
# 203	2
# 204	3
# 205	8
# 206	9
# 207	8
# 208	5
# 209	9
# 21	5
# 210	0
# 211	6
# 212	4
# ...
